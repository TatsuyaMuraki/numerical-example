# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import GPy
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
kernel = GPy.kern.RBF(input_dim=1, variance=1, lengthscale=0.2)

N_sim = 100
x_sim = np.linspace(-1, 1, N_sim)
x_sim = x_sim[:, None]    #入力変数を1列に変更する　or　x_sim.reshape(-1,1)
mu = np.zeros(N_sim)
cov = kernel.K(x_sim, x_sim)       #.Kで共分散行列か？
y_sim = np.random.multivariate_normal(mu, cov, size=4)   #sizeでランダムに生成する正規分布の数を指定, 1行目に一つ目のデータ、二行目に二つ目のデータ
                                       #100次元の正規分布からランダムに１つサンプルする
for i  in range(4):
    plt.scatter(x_sim, y_sim[i], marker='.')

# %%
import GPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kernel = GPy.kern.RBF(1)
# kernel = GPy.kern.RBF(1) + GPy.kern.Bias(1) + GPy.kern.Linear(1)

d = pd.read_csv('http://kasugano.sakura.ne.jp/images/2016/20161112/data-GPbook-Fig2_05.txt')
model = GPy.models.GPRegression(d.X[:, None], d.Y[:, None], kernel=kernel)
model.optimize()
model.plot()

## prediction
x_pred = np.linspace(-10, 10, 100)
x_pred = x_pred[:, None]
y_qua_pred = model.predict_quantiles(x_pred, quantiles=(2.5, 50, 97.5))[0]

plt.plot(x_pred, y_qua_pred,color='red')
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
import GPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kernel = GPy.kern.RBF(1)
# kernel = GPy.kern.RBF(1) + GPy.kern.Bias(1) + GPy.kern.Linear(1)

d = pd.read_csv('http://kasugano.sakura.ne.jp/images/2016/20161112/data-GPbook-Fig2_05.txt')
d_2 = d.copy()
for i in range(1,len(d.X[:, None])):
    plt.xlim(-10, 10)
    plt.ylim(-5, 5)
    model = GPy.models.GPRegression(d.X[:, None][:i], d.Y[:, None][:i], kernel=kernel)
    model.optimize()
    model.plot()
    plt.scatter(d_2['X'], d_2['Y'], marker='o', color='red')
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3124: UserWarning:Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=-6.836950999999999, right=-6.836950999999999
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
import GPy
import numpy as np
import matplotlib.pyplot as plt

kernel = GPy.kern.Matern52(2, ARD=True)

np.random.seed(seed=123)
N = 50
X = np.random.uniform(-3.,3.,(N, 2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2]) + np.random.randn(N,1)*0.05

model = GPy.models.GPRegression(X, Y, kernel)
model.optimize(messages=True, max_iters=1e5)
model.plot()


model.plot(fixed_inputs=[(0, -1.0)], plot_data=False)


## prediction
x_pred = np.array([np.linspace(-3, 3, 100), np.linspace(3, -3, 100)]).T
y_qua_pred = model.predict_quantiles(x_pred, quantiles=(2.5, 50, 97.5))[0]
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=100000), HTML(value=''))), Box(children=(HTML(value='')…
#  /anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
kernel = GPy.kern.Matern52(1, ARD=False)
kernel.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
from sklearn.gaussian_process import kernels as sk_kern

kern = sk_kern.RBF(length_scale=.5)
kern = sk_kern.ExpSineSquared() * sk_kern.RBF()

# ほかにも色々と種類はある。ドキュメント参照
# kern = sk_kern.RationalQuadratic(length_scale=.5)
# kern = sk_kern.ConstantKernel()
# kern = sk_kern.WhiteKernel(noise_level=3.)

# 可視化は定義されていないので自分で用意する必要あり
X = np.linspace(-2, 2, 100)
plt.plot(X, kern(X.reshape(-1, 1), np.array([[0]])))

# %%
X.reshape(-1, 1).shape
# Out:
# (100, 1)

# %%
np.array([[0.]]).shape
# Out:
# (1, 1)

# %%
np.array([[0.]])
# Out:
# array([[0.]])

# %%
A = kern(X.reshape(-1, 1), np.zeros([100,1]))

# %%
X.shape
# Out:
# (100,)

# %%
x_train = np.linspace(-10,10,15).reshape(-1,1)
y_train = np.sin(x_train).reshape(-1,1)

# %%
y_train[0]
# Out:
# array([0.54402111])

# %%
X = np.linspace(-10,10,200)
Y = np.sin(X)

# %%
plt.plot(X,Y)
plt.scatter(x_train, y_train)

# %%
import GPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#kernel = GPy.kern.RBF(1)
kernel = GPy.kern.RBF(1) + GPy.kern.Bias(1) + GPy.kern.Linear(1)

for i in range(2,20):
    plt.xlim(-10, 10)
    plt.ylim(-6,6)
    x_train = (20*np.random.rand(i)-10).reshape(-1,1)
    y_train = np.sin(x_train).reshape(-1,1)
    model = GPy.models.GPRegression(x_train, y_train, kernel=kernel)
    model.optimize()
    model.plot()
    plt.scatter(x_train, y_train, marker='o', color='red')
    plt.plot(X,Y,color = 'yellow')
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
import GPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kernel = GPy.kern.RBF(1) + GPy.kern.Bias(1) + GPy.kern.Linear(1)

for i in range(2,20):
    plt.xlim(-10, 10)
    plt.ylim(-6,6)
    x_train = (20*np.random.rand(i)-10).reshape(-1,1)
    y_train = np.sin(x_train).reshape(-1,1)
    model = GPy.models.GPRegression(x_train, y_train, kernel=kernel)
    model.optimize()
    model.plot()
    plt.scatter(x_train, y_train, marker='o', color='red')
    plt.plot(X,Y,color = 'yellow')
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
kern = GPy.kern.PeriodicExponential(1)
kern.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
print(kern)
# Out:
#   periodic_exponential.  |              value  |  constraints  |  priors
#   variance               |                1.0  |      +ve      |
#   lengthscale            |                1.0  |      +ve      |
#   period                 |  6.283185307179586  |      +ve      |

# %%
x = np.linspace(-5,5,100)
y = np.exp(np.cos(x)/3)

# %%
plt.plot(x,y)

# %%
import GPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


kernels = []
kernels.append(GPy.kern.RBF(1))
kernels.append(GPy.kern.Linear(1))
kernels.append(GPy.kern.PeriodicExponential(1))

np.random.seed(123)

# %% [markdown]
# # 直線の回帰

# %%
x_real = np.linspace(-5,5,100)
y_real = 3 * x_real
plt.plot(x_real, y_real)

x_train = 10 * np.random.rand(10) - 5 
y_train = 3 * x_train + np.random.randn(10)
plt.scatter(x_train, y_train, color='red')


for i in range(len(kernels)):
    model = GPy.models.GPRegression(x_train.reshape(-1,1), y_train.reshape(-1,1), kernel=kernels[i])
    model.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # 曲線の回帰

# %%
x_real = np.linspace(-5,5,100)
y_real = 2 - x_real - 2*x_real**2 + x_real**3
plt.plot(x_real, y_real)

x_train = 10 * np.random.rand(10) - 5 
y_train = 2 - x_train - 2*x_train**2 + x_train**3 + np.random.randn(10)
plt.scatter(x_train, y_train, color='red')


for i in range(len(kernels)):
    model = GPy.models.GPRegression(x_train.reshape(-1,1), y_train.reshape(-1,1), kernel=kernels[i])
    model.optimize()
    model.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # 周期関数の回帰

# %%
x_real = np.linspace(-5,5,100)
y_real = np.sin(x_real)
plt.plot(x_real, y_real)

x_train = 10 * np.random.rand(30) - 5 
y_train = np.sin(x_train) + np.random.randn(30)/10
plt.scatter(x_train, y_train, color='red')


for i in range(len(kernels)):
    model = GPy.models.GPRegression(x_train.reshape(-1,1), y_train.reshape(-1,1), kernel=kernels[i])
    model.optimize()
    plt.plot(x_real, y_real)
    model.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
model = GPy.models.GPRegression(x_train.reshape(-1,1), y_train.reshape(-1,1), kernel=kernels[0])

# %%
model.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
x = np.linspace(-5,5,100)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
x1 = 10*np.random.rand(30) -5

# %%
y1 = np.sin(x1)

# %%
plt.scatter(x1,y1)

# %%
model = GPy.models.GPRegression(x1.reshape(-1,1), y1.reshape(-1,1), kernel = kernels[1])

# %%
model.plot()
# Out:
#  /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
